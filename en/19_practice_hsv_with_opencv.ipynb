# %% [markdown]
# # Task proposal
#
# How to work with Colors within opencv.
#
# Video: [Detecting colors (Hsv Color Space) - Opencv with Python](https://youtu.be/Q0IPYlIK-4A?si=4hbR2m4_Yy-QuRq1) (10:35 minutes)

# %% [markdown]
# # Identifying colors
#
# From objects of different colors, OpenCV is used to identify each color in a specific way. In the example below, I use different windows, each one to identify a color.
#
# The code was run on my local computer. Below is the code, and then prints of my tests.

# %%
import numpy as np
import cv2

cap = cv2.VideoCapture(1)

while True:
    _, frame = cap.read()
    hsv_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)

    # Red color
    low_red = np.array([161, 155, 84])
    high_red = np.array([179, 255, 255])
    red_mask = cv2.inRange(hsv_frame, low_red, high_red)
    red = cv2.bitwise_and(frame, frame, mask=red_mask)

    # Blue color
    low_blue = np.array([94, 80, 2])
    high_blue = np.array([126, 255, 255])
    blue_mask = cv2.inRange(hsv_frame, low_blue, high_blue)
    blue = cv2.bitwise_and(frame, frame, mask=blue_mask)

    # Green color
    low_green = np.array([25, 52, 72])
    high_green = np.array([102, 255, 255])
    green_mask = cv2.inRange(hsv_frame, low_green, high_green)
    green = cv2.bitwise_and(frame, frame, mask=green_mask)

    cv2.imshow("Red", red)
    cv2.imshow("Blue", blue)
    cv2.imshow("Green", green)
    cv2.imshow("Frame", frame)

    key = cv2.waitKey(1)
    if key == 27:
        break

# %% [markdown]
# ![Captura de tela 2023-12-27 120051.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de tela 2023-12-27 120027.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de tela 2023-12-27 115730.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de tela 2023-12-27 115702.png](data:image/png;base64,...)

# %% [markdown]
# Video of operation at: https://youtu.be/gienPrNSEd8
